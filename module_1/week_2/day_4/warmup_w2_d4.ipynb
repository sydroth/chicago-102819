# %% [markdown]
# Import your dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='whitegrid')

# %% [markdown]
# Load dataset and explore it's shape

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Use Seaborn's lmplot or regplot to show a scatter plot and a line of best fit. Use "total_bill" as the x-axis and tip as your y-axis. Experiment with different hues and markers!

# %%
tips['tip_percent']= round(((tips['tip'] / tips['total_bill'])* 100), 2)

# %%
sns.lmplot('total_bill', 'tip', palette='helix', data=tips, scatter=True)

#helix=sns.color_palette("cubehelix")
#sns.stripplot(sns.color_palette("cubehelix"))

# %%
sns.stripplot(x='total_bill', y='tip', data=tips, jitter=0.1, dodge=True, palette="cubehelix", edgecolor='gray', linewidth=.2)
#plt.figure(figsize=(40,10))

# %%
sns.stripplot('day', 'tip_percent', data=tips, jitter=.1, dodge=True, palette="cubehelix", edgecolor='gray', linewidth=1)

# %% [markdown]
# Use a barplot to find out which days expect the highest total bills. Which time of day are women more likely to eat: dinner or lunch? Men?

# %%
sns.barplot('day', 'total_bill', data=tips, hue='sex', palette='cubehelix')

# %% [markdown]
# Use a scatterplot to show the correlation between total bill and tip
# grouped by time of day.  Play around with which markers designate
# which group.

# %%
sns.lmplot('total_bill','tip',data=tips, height=3, aspect=2,
          hue='time', palette='Set1')
